# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
outputfolder = 'output/296GHz/far_field/15_15/'
data=np.genfromtxt(outputfolder +'IF_field.txt',delimiter=',')
N_if =301
IF_x=data[...,0]+1j*data[...,1];
IF_x=IF_x.reshape(N_if,-1)
IF_y=data[...,2]+1j*data[...,3];
IF_y=IF_y.reshape(N_if,-1)
IF_z=data[...,4]+1j*data[...,5];
IF_z=IF_z.reshape(N_if,-1)
#test=test/test[50,50]

# %%
data=np.genfromtxt(outputfolder +'source_field.txt',delimiter=',')
Ns =501
S_co=data[...,0]+1j*data[...,1];
S_co=S_co.reshape(Ns,-1)
S_cx=data[...,2]+1j*data[...,3];
S_cx=S_cx.reshape(Ns,-1)

# %%
plt.pcolor(np.log10(np.abs(IF_x))*20,cmap = 'jet',vmax = 20, vmin=-100)
cbar = plt.colorbar()
plt.show()

plt.pcolor(np.log10(np.abs(IF_y))*20,cmap = 'jet',vmax = 20, vmin=-100)
cbar = plt.colorbar()
plt.show()

plt.pcolor(np.log10(np.abs(IF_z))*20,cmap = 'jet',vmax = 20, vmin=-100)
cbar = plt.colorbar()
plt.show()

# %%
plt.pcolor(np.log10(np.abs(S_co))*20,cmap = 'jet')#,vmax = 20, vmin=-100)
cbar = plt.colorbar()
plt.show()

plt.pcolor(np.log10(np.abs(S_cx))*20,cmap = 'jet')#,vmax = 20, vmin=-100)
cbar = plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(np.log10(np.abs(S_co[int(Ns/2),:]))*20)#,vmax = 20, vmin=-100)
plt.xlim([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 fig = plt.figure(figsize=(10,5))
#       2 plt.plot(np.log10(np.abs(S_co[250,:]))*20)#,vmax = 20, vmin=-100)
# ----> 3 plt.xlim([])
#       4 plt.show()
#
# File ~/miniconda3/envs/ccatholo/lib/python3.9/site-packages/matplotlib/pyplot.py:1720, in xlim(*args, **kwargs)
#    1718 if not args and not kwargs:
#    1719     return ax.get_xlim()
# -> 1720 ret = ax.set_xlim(*args, **kwargs)
#    1721 return ret
#
# File ~/miniconda3/envs/ccatholo/lib/python3.9/site-packages/matplotlib/axes/_base.py:3511, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3444 """
#    3445 Set the x-axis view limits.
#    3446
#    (...)
#    3508
#    3509 """
#    3510 if right is None and np.iterable(left):
# -> 3511     left, right = left
#    3512 if xmin is not None:
#    3513     if left is not None:
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
plt.plot(np.log10(np.abs(ref[50,...])));
plt.plot(np.log10(np.abs(test[50,...])))

# %%
plt.pcolor((test-ref).real)
plt.colorbar()
plt.show()
plt.pcolor((test-ref).imag)
plt.colorbar()
plt.show()

# %%
err=(test-ref)

# %%
np.log10((np.abs(err)**2).mean())*10
# Out:
# -65.69981365970521
