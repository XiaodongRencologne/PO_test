# %%
import numpy as np
import matplotlib.pyplot as plt
from Kirchhoffpy.dielectric_film import film

c = 299792458

# %% [markdown]
# ## Film parameters
# * 1. thickness: h = 2mm
# * 2. n = 1.54
# * 3. frequency range 80-90GHz

# %%
h = 2
n = 3.36
freq_list = np.linspace(80-10,80+10,2001)
h_list = np.linspace(1,100,2001)

# %%
def film_h():

# %%
Lambda_list = c*1000/(freq_list*10**9)
R, T = film(h,
            1,n,1,
            0,
            Lambda_list,
            polarization = 'perpendicular')

# %%
fig, ax = plt.subplots(1,1, figsize=(20,5))
ax.plot(freq_list,T*100)
ax.set_xlabel('freq (GHz)')
ax.set_ylabel('Transimission %')
# Out:
# Text(0, 0.5, 'Transimission %')
